# %%
#Task 3.1
def count_vowel(x):
    x = x.lower()
    vowels = 0
    vowel = "aeiou"
    for i in range(len(x)):
        if x[i] in vowel:
            vowels += len(x[i]) #This is unneccessary, as the len of 1 char is always 1
    return vowels

#Test cases to check
print("Task 3.1 Test cases")
print(count_vowel("Ding")==1)
print(count_vowel("Budum")==2)
print(count_vowel("speakers")==3)

# Task 3.1: 4/4
# Correct use of str.lower()                     1m
# Correct use of loop to iterate through word    1m
# Correct use of membership for vowel            1m
# Correct increment of counter                   1m
# Out:
# Task 3.1 Test cases
# True
# True
# True

# %%
song = "Ding ding, a ring a ding ding ding! \
Budum, budum, hark the speakers swing! \
Ding ding, a ba da ba bomo zing! \
Budum, budum, doing our own thing! \
Oh oh oh, budum, ding! \
Let the crazy rhythm ring! \
Na na na, budum, ding! \
Everybody jump and sing!"
#Task 3.1
def count_vowel(x):
    x = x.lower()
    vowels = 0
    vowel = "aeiou"
    for i in range(len(x)):
        if x[i] in vowel:
            vowels += len(x[i])
    return vowels
    
#Task 3.2
def song_genre(x):
    percvowles = (vowels/len(x)) * 100 ## You should be making use of count_vowel() here
    if percvowels > (35/100): ##Should be 35 and not 35/100
        return "Ballad"
    elif percvowels < 36: ##Should be <= 35, not <36
        return "Electropop"

#Task 3.2 Test cases to check
print("Task 3.2 Test cases")
print(song_genre(song)=="Electropop")

# Task 3.2: 1/6
# Incorrect use of str.split()                     0m
# Correct use of len() to find total words         1m
# Incorrect use of count_vowel function            0m
# Incorrect % calculation                          0m
# Incorrect conditions for % check                 0m
# None of outputs relevant and appropriate         0m

#Task 3 Total: 5/10
# Out:
# Task 3.2 Test cases
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 29
#      27 #Task 3.2 Test cases to check
#      28 print("Task 3.2 Test cases")
# ---> 29 print(song_genre(song)=="Electropop")
#      31 # Task 3.2: 6/6
#      32 # Correct use of str.split()                     1m
#      33 # Correct use of len() to find length of word    1m
#    (...)
#      38
#      39 #Task 3 Total: 10/10
#
# Cell In[6], line 21, in song_genre(x)
#      20 def song_genre(x):
# ---> 21     percvowles = (vowels/len(x)) * 100
#      22     if percvowels > (35/100):
#      23         return "Ballad"
#
# NameError: name 'vowels' is not defined
