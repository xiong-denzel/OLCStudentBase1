# %%
# Do not change the values of these variables
s1 = "We went to London bridge to"
s2 = "The wheels on the tricycle go"
w1 = "sing"
w2 = "zing"
n = 5
fill = "la"

# Errors from this line onwards
last2letters = w1[-2:] # 1m
if last2letters in w2:	 # 0m
    s1 = s1 + " " + w1
    s2 = s2 + " " + w2 # 1m
    line = (fill + " ") * n  # 1m
    line = line[:-1]
    print(s1 + "\n" + line + "\n" + s2 + "\n" + line)
else: 
    print("words do not rhyme") # 1m

# TASK 2: 4/5
# even your file naming is wrong. TikTok is DESTROYING your brain!!
# Out:
# We went to London bridge to sing
# la la la la la
# The wheels on the tricycle go zing
# la la la la la
