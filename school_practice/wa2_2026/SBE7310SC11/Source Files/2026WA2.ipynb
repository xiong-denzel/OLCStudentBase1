# %%
#Task 3.1
song = "Ding ding, a ring a ding ding ding! \
Budum, budum, hark the speakers swing! \
Ding ding, a ba da ba bomo zing! \
Budum, budum, doing our own thing! \
Oh oh oh, budum, ding! \
Let the crazy rhythm ring! \
Na na na, budum, ding! \
Everybody jump and sing!"
def song_genre(x):
    x = x.lower()
    vowels = 0
    vowel = "aeiou"
    for i in range(len(x)):
        if x[i] in vowel:
            vowels += len(x[i])
    return vowels
    percvowles = (vowels/len(x)) * 100
    if percvowels > (35/100):
        return "Ballad"
    elif percvowels < 36:
        return "Electropop"
    
print(count_vowel(song))
def song_genre(x):
# Out:
#   Cell In[1], line 26
#
#     ^
# SyntaxError: unexpected EOF while parsing
